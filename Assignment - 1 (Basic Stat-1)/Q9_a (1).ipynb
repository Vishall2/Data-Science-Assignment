# %%
import pandas as pd
import numpy as np
from scipy.stats import kurtosis
from scipy.stats import skew

# %%
Q9_a_df = pd.read_csv("D:/ExcelR/Assignments/Assignment - 1/Q9_a.csv")

# %%
Q9_a_df
# Out:
#     Index  speed  dist
# 0       1      4     2
# 1       2      4    10
# 2       3      7     4
# 3       4      7    22
# 4       5      8    16
# 5       6      9    10
# 6       7     10    18
# 7       8     10    26
# 8       9     10    34
# 9      10     11    17
# 10     11     11    28
# 11     12     12    14
# 12     13     12    20
# 13     14     12    24
# 14     15     12    28
# 15     16     13    26
# 16     17     13    34
# 17     18     13    34
# 18     19     13    46
# 19     20     14    26
# 20     21     14    36
# 21     22     14    60
# 22     23     14    80
# 23     24     15    20
# 24     25     15    26
# 25     26     15    54
# 26     27     16    32
# 27     28     16    40
# 28     29     17    32
# 29     30     17    40
# 30     31     17    50
# 31     32     18    42
# 32     33     18    56
# 33     34     18    76
# 34     35     18    84
# 35     36     19    36
# 36     37     19    46
# 37     38     19    68
# 38     39     20    32
# ...

# %%
Q9_a_df = pd.DataFrame(Q9_a_df)

# %%
Q9_a_df.drop(['Index'],axis=1,inplace=True)

# %%
print(Q9_a_df.head())
# Out:
#    speed  dist
# 0      4     2
# 1      4    10
# 2      7     4
# 3      7    22
# 4      8    16

# %%
Q9_a_df.kurt()
# Out:
# speed   -0.508994
# dist     0.405053
# dtype: float64

# %%
Q9_a_df.skew()
# Out:
# speed   -0.117510
# dist     0.806895
# dtype: float64

# %%
Q9_a_df.plot(kind='density')
# Out:
# <AxesSubplot:ylabel='Density'>
